# %%
#inferential statistics 


#EDA is basically descriptive statistics.
#inferential statistics is confirmation of what we found in EDA.
#let EDA says group A spends more than Group B then inferential statistics tests whether that 
#difference is statistically significant and not due to chances.

#making inferences predictions about the population through sammple.

#it involves using statistical techniques to test hypothesis and draw conclusions from data.
#without hypothesis you risk drawing wrong conclutions and making ba decisions.
#based on score level aplha level of significance -- we decide to accept or reject hypothesis.
#IF P value less than alpha reject null hypthesis.
#error in wrongly accepting or rejecting null hypthesis. type 1 error false positive --- type 2 error false negative[when null hyp accepted when it is false]

#hyothesis testing
#level of significance 
#p value
#null hypotheis either reject or fail to reject we will not say accept.
#if p value less than 0.05 reject null hyp. accept alternative hyp.
#if p greater than 0.05 fail to reject null hyp.


#hypothesis testing
#confidence intervals
#analysis of variance ANOVA
#Reg analysis... pred. sales of a product based on advertising expenses.
#chi square test
#sampling techniques
#bayesian statistics

# %%
#etra info   dont mix with t test z test....

#student t distribution.. used when sample size small less and equal to 30 sample size.
#CI=point estimation + or - margin of error         ME=critical value * [population sd/sq root of sample size] no if population SD unknow
#and sample size less than 30. bcz sample size very samll therefore cant find population SD therefore we use sample SD.
#degree of freedom n-1  as df will increase you Student t dist will become z distribution.

#z distribution also called standard ND, z score   z= [x-mew]/sigma

# %%
#parametric tests
#applied on ND
#more reliable results
#we have to meet assumptions to use PTs
#different features can be compared 2 15 16 18 20 and 25 38 52 100

#non parametric tests
#less reliable results bcz no assumptions
#if both features same then only compare possible


#assumptions of PTs
#normality test-- shapiro wilk test -- kolmogorov smirnov test
#through graphs we can also check.
#homogeneity test
#variance of the variable in data are equal. spread from center should be same.
#levenes test
#shows kortosis if more kortosis more spread


#choose a statistical test from 3 main families
#1__chi square 
#purpose camparison data categorical only.
#for categorical variables compare only.
#chi sq test of homogeneity check distribution of one categorical column. let veg and non veg are 50% each in that one column
#chi sq test of independence.
#example titanic survived 1 or 0 ---- sex male female -- both are categorical variables
#null hyp. no sig association btw sex and surived 
#alter there is asso.
#p less than 0.05 reject h not.. null hyp.
#so there is relation bcz female were given pref when titanic was about to drown.
#gender has impacted surivival.








#2__t or Z test/ ANOVA
#purpose comparison data categorical and numerical

#only diff btw t and z is if sample size greater than 30 and pop SD known z is used. if SD not known use t or if sd known but sample size less than 30 use t again.
#in formula we use population SD in z test. while sample sd in t test.
#t score or z score find.

#one sample t or Z test for one sample group with a known mean.
#only one sample let age compare with let age 50.

#two sample t or Z test
#unpaired t or ztest two diff groups independent male femaole age compare
#paired t or z test same group twice female age in 2019 and 2023.

#ANOVA 
#used when more than 2 variables compare mean sd.
#f score find. so also called f test. f statistic.
#null hyp.. all samples mean are equal     alternate hyp... at least one pair of sample is sig. diff.

#one way ANOVA even one of group is signifi you will get sig results but diesnt tell you wich one.
# 3 class 1 2 3 and 3 sample avg score Class 1 , score 2, score 3... we see sig diff of their mean. if sig diff or not?
# null hyp... mew1=mew2=mew3  alternate 3 different alternate hyo... mew1 notEqualTo mew2 equalTo n=mew3 or 
#new1 equal mew2 not equal mew3 or mew1 notequal mew2 not equal mew3

#two way ANOVA
#repeated measures of ANOVA scale up of paired t test 2 or more variables.
#more than 1 factor variables 2 factors effect response variable..
#fertilizer and planting density effect on greater crop yeild. factors are independed variable and response is dependent variable.
#f statistic mean square btw groups/ mean square within groups   MSB/MSW
#MSB = SSB/degree of freedom df      df=k-1



#3__correlation
#purpose relationship data numerical
#pearsons correlation one indep and one dep variable
#regression one indep and one dep variable

# %%
#these tests will give reliable results if assumptions fulfilled
#normal and homogeneity
#if not normal then try normalize your data log transformation or min max scaling standardization
#if it doesnt get normalize then use non parametric tests.

#non parametric tests also 3 types
#chi squared
#t z test/ ANOVA
#correlation

# %%
#other tests
#ANOVA  analysis of variance
#ANCOVA analysis of covariance
#MANOA multivariate analysis of variance
#MANCOVA ...... of covariance

# %%
#hypothesis testing
#null hypothesis alternative hypothesis
#data collection to tests the hypothesis
#statistical analysis
#results reporting

#null hypotheis either reject or fail to reject we will not say accept.
#if p value less than 0.05 reject null hyp. accept alternative hyp.
#if p greater than 0.05 fail to reject null hyp.
