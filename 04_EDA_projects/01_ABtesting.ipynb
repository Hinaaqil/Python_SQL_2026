# %%
#A/B Testing & Regression Analysis

# %%
#business problem
#marketing agency - main objective max. ROI for our clients advertising campaigns.
#2 ad campaigns conducted on facebook and AdWords - need determine which platform yeilds better results - in terms of clicks conversions
# and overall costeffectiveness  --  identify most effective platform -- then can allocate resources more effectively and can
#optimize our adv strategies to deliver better results for our clients.

# %%
#research question
#which ad platform is more effective in terms of conversions clicks overall cost effectiveness? by comparing the data of 2 platforms

# %%
### A/B testing    hypothesis testing    regression analysis

# %%
#pip install seaborn
#!pip install scipy

# %%
#pip install scikit-learn statsmodels

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as st

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import coint
import warnings
warnings.filterwarnings('ignore')

# %%
#data description
#data related to 2 ad compaings conducted year 2019. 365 days rows full year. data set includes different performance metricsof each
#ad compaign -- info on over time effectiveness efficiency.

#key features 
#date 1st jan to 31st dec.    
#Ad Views   Ad Clicks   Ad Conversion   
#Cost per ad   CTR click through rate-ratio of clicks to views
#Conversion rate ratio of conver. to clicks    
#cost per click CPC avg cost incurred per click an the ad.

# %%
df = pd.read_csv('marketing_campaign.csv')

# %%
df.head

# %%
df.shape

# %%
df.dtpes
