# %%
#info about how to do analysis 
#diff types of analysis
#diff types of industries and questions in each we see daily
#interview questions

# %%
#projects to do..

# %%
#vendor performance sql python power bi

#python project 2 Marketing campaign
#no sql used direct files analyzed in pandas dataframe.
#hyp testing -- time series analysis -- regression analysis
#

# %%
#SQL
#sql database create -- table create -- clean -- transform(new columns) -- querying -- write a report paste queries used and insights.
#then connect with vs code python and analyze like above 7 steps.
#write report and upload on gitub.

# %%
#power bi data modeling and dax and report
#power bi complex data modeling project and report and upload github.
#power bi 2 dashboards.

#power bi designs -- create proper dashboards

# %%
#Excel Dashboard
#power query power pivot etc.. 

#google sheet

# %%
#ML DL NLP Projects
#

# %%
#FP&A
#old job explain
#REIT financial st items structure

# %%
#############################################################################################

# %%
#In office when you get a request
#annual analysis, monthly/quarterly analysis, Period comparison, variance analysis, root-cause analysis,Ad-hoc,Forecast
#Recurring report - Give me this information regularly like Daily sales report,Weekly performance report
#first see what anaysis type it falls.. customer analysis? inventory analsyis? profitability anaysis? sales analysis?
#then think of questions related to that anaysis type.
#that will help you answer the questions they have asked.
#when the question is WHY this thing happened? ask AI for possible reasons? ask it what things tables to check? plus also ask
#proper way to check what Calculations KPIs or other measures find all steps?


#Before you can answer business questions, you need to understand three things:
#1. The business 
#How does the company make money?  #For Foodpanda, for example: #Customers place orders. #Restaurants prepare food. #Riders deliver it.
#Foodpanda earns commissions, delivery fees, subscriptions, ads, etc.
#If you don't understand the business, you won't know what to analyze.

#2. The database 
#You need to know what tables exist.
#For example:
#Customers
#Orders
#Restaurants
#Riders
#Payments
#Refunds
#Promotions
#Cities

#3. How the tables are connected 

#When someone asks:
#"Which restaurants have the highest repeat customers?"
#You immediately know: Customers table - Orders table - Restaurants table  -- Join them and analyze.

#Real interview example
#The manager asks:
#"Why did revenue fall in Lahore last month?"
#Immediately you're thinking:
#Which tables do I need? Orders - Payments - Promotions - Customers - Cities

#Then you investigate:
#Were there fewer orders?
#Lower average order value?
#More discounts?
#More failed payments?
#Fewer active customers?



#HOW to answer questions
#why did rev fall in lahore last month?
#which tables do i need?
#ask AI for reasons list ... fewer orders? lower avg order value? more discounts? fewer active customers?
#according to these do analysis and find the reason.

#data analyst
#what happened explain -- full analysis and dashboard
#why happened? agg/join and create 1 summary table or more   --- or direct extract if possible
#the answer using slicing(groupby agg).

# %%
#Projects

# %%
#retail(Walmarts, Metro, Carrefour)
#Daily questions
#Which products sell the most?
#Which products should be discounted?
#Which stores perform best?
#Which vendors are most profitable?
#Which inventory is sitting too long?



#Telecommunications -- why customers leaving
#Daily questions
#Why are customers leaving?
#Which internet packages are popular?
#Which areas have network problems?
#Which plans generate the most revenue?
#Which customers use the most data?

#jazz
#Product Performance
#Business asks: "How is our monthly internet package performing?"
#You analyze:
#Number of users who subscribed
#Revenue generated
#Which cities are buying the package
#Whether subscriptions are increasing or decreasing
#Recommendation:
#Increase marketing in cities where adoption is low.
#Improve or retire packages that consistently underperform.

#Campaign Analysis
#Marketing asks: "We sent an SMS offer to 5 million customers. Did it work?"
#You compare:
#Customers who received the SMS
#Customers who activated the offer
#Revenue before and after the campaign
#Conversion rate
#Then you answer:
#Was the campaign successful?
#Should we repeat it?

#Customer Analysis
#The product team asks: "Why are customers leaving?"
#You analyze: Customer churn - Recharge frequency -Data usage - Calling patterns - Customer segments
#You might find: "Customers using less than 2 GB per month are much more likely to stop using Jazz."
#The business can then design a better package for those customers.
    
#Dashboard Development
#Executives need dashboards showing:
#Daily revenue - Subscribers - ARPU (Average Revenue Per User) - Active users - Campaign performance
#You build or update dashboards in Power BI or Tableau so management can monitor these KPIs every day.

#Ad hoc Analysis
#CEO might ask: "Revenue dropped by 8% this week. Why?"
#You investigate: Which city? Which product? Which customer segment? Any network outages? Any failed campaign?
#Then you explain the root cause and suggest actions. This kind of "why did this happen?" analysis is common.



##################################################################################################################





#ecommerce(Daraz, Amazon)
#Daily questions
#Which products are trending?
#Why are customers abandoning carts?
#Which sellers perform best?
#Which promotions increased sales?
#Which products receive the most returns?



#ecommerce
#You arrive and receive a message from the Finance Director.
#"Our payment processing costs increased by 12% this month. Can you find out why?"
#You start by querying millions of payment records using SQL (BigQuery).

#You analyze data such as: #Credit card payments #Cash payments #Wallet payments #Refunds #Failed transactions #Delivery fees #Merchant commissions
#You discover: #Failed card payments increased in one country. #or #One payment provider increased its fees.

#You prepare charts and dashboards. #Instead of saying #Costs increased.
#You explain #"Most of the increase comes from Visa transactions in Pakistan because transaction volume increased by 30%."

#Now management understands the reason.


#Another request arrives. #"Did our cashback campaign actually make money?"
#You compare
#Before campaign: Orders - Revenue - Profit
#After campaign: Orders - Revenue - Cashback cost
#You conclude: Orders increased 18%, but profit only increased 3%.
#Recommendation: Reduce cashback from 20% to 10%.


#FinTech team asks #"Which payment partner gives us the lowest processing fee?"
#You compare Partner A 2.4% fee    #Partner B 2.0%     #Partner C 3.1%
#Recommendation #Move more transactions to Partner B.

#Management asks "How much money do we lose from refunds?"
#You calculate Refund rate #Refund amount #Cities #Restaurants #Payment method
#You discover #70% of refunds happen because restaurants reject orders.
#Recommendation #Improve restaurant acceptance rate.


#You update executive dashboards showing
#Revenue Orders Payment volume Commission Refunds Processing costs Profit KPIs
#The CFO checks these dashboards daily.


#Revenue #Why did revenue drop? #Which country is growing fastest? #Which payment method generates most revenue?

#Payments #Why are payments failing? #Which payment provider is cheapest? #Which provider has the highest success rate?

#Campaigns Did cashback increase profit? #Was free delivery worth it? #Which promotion had the best ROI?

#Restaurants #Which restaurants cancel most orders? #Which cities generate highest commissions? #Which merchants are most profitable?

#Customers #Which customers order most? #Why are customers leaving? #Which customers use wallets vs cards?

#Finance #Where are costs increasing? #Which countries have highest margins? #Where can we reduce expenses?


######################################################################################################

#logistics & supply chain
#Daily questions
#Which deliveries are late?
#Which routes cost the most?
#Which warehouse performs best?
#Which suppliers delay shipments?
#How can transportation costs be reduced?

# %%
#Analysis Types

# %%
#Operational Analysis   KPIs - Delivery time, Cost per delivery
#Risk Analysis
#Financial Analysis FP&A   KPIs - Gross Margin, Net Margin, EBITDA, Operating cost.
#Customer Analysis
#Marketing Analysis  KPIs - CAC ROAS Conversion rate
#Procurement Analysis - vendors
#Inventory Analysis - products
#Profitability Analysis
#Sales Analysis - KPIs - revenue, unit sold, avg order value.


#Operations:
#Which warehouse has the most delayed shipments?
#You analyze logistics data and report your findings.

# %%
#Customer Analysis
#customer retension is falling what data would you analyze? customer segments, order freq, churn rate, product usage, complaints,
#customer support

#Daily questions
#Who are our best customers?
#Which customers stopped buying?
#Which customers buy frequently?
#Which customers spend the most?
#What products do customers buy together?

#Departments - CRM, Marketing, Sales


#Customer retention is falling. What data would you analyze?
#Customer segments - Order frequency - Churn rate - Product usage - Complaints - Customer support

# %%
#Marketing Analysis  KPIs - CAC ROAS Conversion rate

#marketing spent $1M. how would you know if it worked? calculate ROI, Conversion, revenue increase, profit increase, CAC, ROAS.

#Daily questions
#Which promotion increased sales?
#Which advertisement generated the highest revenue?
#Which campaign failed?
#Which customer segment responds best?
#Did discounts increase profit or only sales?

#Departments - Marketing, Sales

#Marketing Manager: "Did our Independence Day promotion increase sales?" 


##########################################################################
Marketing asks:

"We spent Rs. 5 million on Facebook ads. Was it worth it?"

You compare:

Sales before the campaign
Sales during the campaign
Profit after discounts
Customer purchases

You conclude:

"Sales increased 18%, but profit only increased 2% because discounts were too large."

Recommendation:

"Use smaller discounts next time."


######################################
#Marketing:
#Which campaign brought the highest-paying customers?
#You analyze campaign data and provide the answer.


##################################
#Q4 #Marketing spent $1M. How would you know if it worked?
#Calculate ROI - Conversion - Revenue increase - Profit increase - CAC - ROAS

# %%
#Procurement Analysis - vendors
#which vendors are cheapest?

#Daily questions
#Which vendors are cheapest?
#Which vendors deliver late?
#Which vendor quality is poor?
#Which vendors receive most of our spending?
#Should we negotiate prices?
#Does buying in bulk reduce cost?

#Departments - Procurement, Supply Chain

###############################################
"Which vendors caused most of our inventory costs this quarter?"

You analyze:

Purchase amounts
Inventory turnover
Unsold stock
Capital locked

You prepare a short report.

# %%
#Inventory Analysis - products
#which products oversold? running out?

#Daily questions
#Which products are running out?
#Which products are overstocked?
#Which inventory moves slowly?
#How much money is locked in inventory?
#Which products will stock out next week?
#Which warehouse has excess inventory?

#Departments - Inventory, Warehouse, Supply Chain

#Inventory Manager: "Why is Warehouse B running out of cooking oil?"

# %%
#Sales Analysis - KPIs - revenue, unit sold, avg order value.

#Daily questions
#Which products are declining?
#Which region is performing best?
#Why did sales drop this week?
#Which customers buy the most?
#Which salesperson is performing best?
#Which stores missed their targets?

#Departments using it -- Sales, Marketing, Management



#########################################################
#Sales Manager: "Sales dropped in Karachi yesterday. Can you investigate?"
#Get the data
#You write SQL queries or use existing reports.

#Example:
#yesterday's sales #Inventory levels #Promotion data #Customer purchases
#You export the data into Excel or Python.

#Clean the data
#You notice: #Missing values #Duplicate records #Wrong dates #Product names spelled differently
#You clean and prepare the data.

#Start investigating
#For the sales drop:
#You compare:
#Yesterday vs last week #Karachi vs Lahore #Store by store #Product by product

#You discover:
#Rice sales are normal. #Milk sales dropped by 40%. #One warehouse ran out of milk.
#So the real reason wasn't lower customer demand—it was stockouts.

#Meet with the Sales Manager
#Manager asks:
#"Why did sales drop?"
#You explain: "Customers wanted milk, but it wasn't available. We estimate we lost Rs. 2 million in sales."

#Manager asks:
#"What should we do?" #You recommend: #Increase safety stock. #Reorder earlier. #Monitor inventory daily.


##################################################################################################

#Manager: "Sales dropped in Lahore last month. Can you find out why?"
#You might discover:
#One top-selling product was out of stock.  #A competitor lowered prices.   #A promotion ended.
#Fewer customers visited stores because of bad weather.
#Instead of just saying "Sales dropped," you explain why they dropped and what the company should do next.

###################################################################
#Yesterday revenue dropped 20%. What would you do?
#A strong answer is:
#Confirm the drop is real (check data quality). 
#Break revenue into: Orders, Average Order Value, Active Customers
#Compare by: Country City Product Customer segment Time
#Look for recent changes: Pricing Promotions Inventory Payment failures Website or app issues Identify the root cause.
#Recommend actions to fix it.

#Revenue dropped 12% this month. Why?
#You analyze the data and answer that specific question.


#Q1 #Revenue dropped by 15%. How would you investigate?
#They want to hear your approach.
#Example: Check which product. - Check which region. - Check customer segments. - Check pricing. - Check promotions. - Check inventory.
#Check competitors.

#Q2 #Profit decreased but sales increased. Why?
#Possible reasons: Costs increased. - Discounts were too high. - Product mix changed. - Shipping costs increased. - Returns increased.


#Customer retention is falling. What data would you analyze?
#Customer segments - Order frequency - Churn rate - Product usage - Complaints - Customer support

#Q4 #Marketing spent $1M. How would you know if it worked?
#Calculate ROI - Conversion - Revenue increase - Profit increase - CAC - ROAS

# %%
#Profitability Analysis

#Daily questions
#Which products make the highest profit?
#Which products lose money?
#Which brands have high sales but low margins?
#Which customers are profitable?
#Which vendor gives us the best margins?
#Which discounts reduce our profits?

#Departments -- Finance, Pricing, Procurement


#Q2 #Profit decreased but sales increased. Why?
#Possible reasons: Costs increased. - Discounts were too high. - Product mix changed. - Shipping costs increased. - Returns increased.

# %%
#Financial Analysis

#Daily questions
#Did we meet our monthly budget?
#Why are expenses increasing?
#Which department spends the most?
#What is our monthly profit?
#Which business unit is growing?

#Departments - FP&A, Finance


#FP&A Analyst - Focuses specifically on the company's financial performance and planning.
#Examples:
#Why did revenue differ from the budget? #Why were expenses higher than expected? #What is next quarter's revenue forecast?
#What will profits look like next year? #Should we increase or reduce spending? 
#FP&A works closely with finance leadership and executives.

# %%
#Operational Analysis

#Daily questions
#Why are deliveries late?
#Which process is slow?
#Which employees complete the most work?
#Where are bottlenecks?
#How can we reduce processing time?

#Departments - Operations, Management

# %%
#Risk Analysis

#Daily questions
#Which customers may default?
#Which loans are risky?
#Which vendors are unreliable?
#Which regions have higher fraud?
#Which transactions look suspicious?

#Departments - Credit Risk, Risk Management

# %%
#A common case interview

#Interviewer:
#Yesterday revenue dropped 20%. What would you do?
#A strong answer is:
#Confirm the drop is real (check data quality). 
#Break revenue into: Orders, Average Order Value, Active Customers
#Compare by: Country City Product Customer segment Time
#Look for recent changes: Pricing Promotions Inventory Payment failures Website or app issues Identify the root cause.
#Recommend actions to fix it.

#Revenue dropped 12% this month. Why?
#You analyze the data and answer that specific question.

#Marketing:
#Which campaign brought the highest-paying customers?
#You analyze campaign data and provide the answer.

#Finance:
#Why did our profit decrease even though sales increased?
#You investigate costs, discounts, returns, and margins.

#Operations:
#Which warehouse has the most delayed shipments?
#You analyze logistics data and report your findings.

#Q1 #Revenue dropped by 15%. How would you investigate?
#They want to hear your approach.
#Example: Check which product. - Check which region. - Check customer segments. - Check pricing. - Check promotions. - Check inventory.
#Check competitors.

#Q2 #Profit decreased but sales increased. Why?
#Possible reasons: Costs increased. - Discounts were too high. - Product mix changed. - Shipping costs increased. - Returns increased.


#Customer retention is falling. What data would you analyze?
#Customer segments - Order frequency - Churn rate - Product usage - Complaints - Customer support

#Q4 #Marketing spent $1M. How would you know if it worked?
#Calculate ROI - Conversion - Revenue increase - Profit increase - CAC - ROAS


#2. KPI Questions
#What KPI would you use for...
#Marketing? CAC - ROAS - Conversion Rate -Sales?

#Revenue Units Sold Average Order Value

#Operations? Delivery Time - Cost per Delivery

#Finance? Gross Margin - Net Margin - EBITDA - Operating Cost


#3. Dashboard Questions
#They may ask

"What would your CEO dashboard include?"

You might answer:

Revenue
Profit
Orders
Active Customers
Churn
Growth
Operating Costs
Cash Flow
KPIs






4. SQL Questions

Example

Find top 10 customers by sales.

Find duplicate customers.

Calculate monthly revenue.

Find customers who didn't order this month.

Running totals.

Window functions.

Joins.

Group By.

CTEs.



5. Python Questions

Read CSV

Merge data

Missing values

Groupby

Pivot Tables

Visualization

Forecasting

Automation

Pandas

NumPy







6. Statistics

Difference between

Mean

Median

Mode

Standard Deviation

Confidence Interval

Hypothesis Testing

P-value

Correlation

Regression

A/B Testing











7. Data Cleaning

What if

Missing values?

Duplicates?

Wrong dates?

Negative quantities?

Outliers?









8. BI Questions

How do you build dashboards?

Which charts?

How do executives use dashboards?

How do you measure KPIs?








9. Finance Questions

Revenue

Gross Profit

Net Profit

Operating Margin

Cash Flow

Budget

Forecast

Variance

P&L

ROI




10. Scenario Questions

CEO asks

"Our costs increased."

What do you do?

Marketing asks

"Our campaign failed."

What do you analyze?

Operations asks

"Deliveries are late."

What metrics?

Finance asks

"We need to reduce costs."

How do you identify opportunities?









11. Behavioral Questions

Tell me about yourself.

Biggest project.

Difficult stakeholder.

Missed deadline.

Mistake.

Conflict.

Why our company?




12. Product Questions (Foodpanda, Uber, Apple)

Foodpanda

Why are refunds increasing?

Why are orders falling?

Which restaurants perform best?

Which cities grow fastest?

Apple

Why are warranty costs increasing?

Forecast next quarter.

Reduce logistics costs.

Improve inventory.





13. AI Questions (becoming common)

How would you use ChatGPT or Claude?

How would you automate reporting?

How would you build an AI assistant for finance?

How would you use LLMs with SQL?





#CV projects results related questions

# %%
###################################################### end #########################################

# %%
#Data Analyst
#Imagine revenue drops.
#Finds the cause:
#"Revenue dropped because customer orders fell by 15% after the discount campaign ended."

#FP&A
#Takes that information and asks:
#"If this continues for the next three months, how much profit will we lose? Should we increase the marketing budget or revise our annual forecast?"

#So:
#Data Analyst = Detective 🔍
#Finds out what happened and why.
#FP&A = Planner 📊
#Decides what the financial impact is and what the company should plan to do next.

# %%
#Customers buy products
#        ↓
#Millions of transactions are stored
 #       ↓
#Database Tables
#(Orders, Sales, Vendors, Inventory, Payments...)
 #       ↓
#Data Analyst
#"What happened?"
#"Why did it happen?"
 #       ↓
#FP&A
#"What will happen?"
#"What should we budget?"
#"What is the financial impact?"
 #       ↓
#CEO/CFO
#"What decision should we make?"

# %%
#Dashboard shows:
#Revenue ↓ 15%
#Profit ↓ 10%
#Data Analyst investigates

#Finds:

#Vendor A's products were out of stock.
#Customers couldn't buy them.
#Lost sales = Rs. 25 million.

#FP&A asks
#"If this continues for the next 6 months..."

#Revenue will miss the annual target by Rs. 150 million.
#Profit will decrease by Rs. 40 million.

#CEO decides
#Increase purchases from Vendor A.
#Add a second supplier to avoid stockouts.
#Increase inventory safety stock.

# %%
#Data Analyst asks:

#"What happened and why?"

#Examples:

#Why did revenue drop in Lahore?
#Which restaurants have the highest cancellations?
#Which campaign performed best?
#Which payment method has the most failures?

#The output is insights.

# %%
#FP&A (Financial Planning & Analysis) asks:

#"What should our financial plan be?"

#Example 1: Budget

#The CEO says:

#"Next year we want to grow by 20%."

#FP&A prepares the budget.

#Item	Budget
#Revenue	Rs. 12 billion
#Marketing	Rs. 1.2 billion
#Salaries	Rs. 2 billion
#Delivery Costs	Rs. 3 billion
#Profit Target	Rs. 2 billion



#Example 2: Forecast

#Halfway through the month:

#The dashboard shows sales are lower than expected.

#FP&A asks:

#"Based on current trends, what will revenue be by month-end?"

#They forecast:

#Planned revenue: Rs. 1 billion
#Forecast: Rs. 920 million

#Now management knows they may miss the target.      




#Example 3: Variance Analysis

#Budget:

#Marketing = Rs. 100 million

#Actual:

#Marketing = Rs. 135 million

#FP&A explains:

#"Marketing spent Rs. 35 million more than planned because of three additional campaigns."




#Example 4: New Expansion

#CEO asks:

#"Should we launch Foodpanda in Gilgit?"

#FP&A builds a financial model.

#Estimated:

#Revenue = Rs. 500 million

#Costs:

#Riders
#Offices
#Marketing
#Employees

#Projected profit:

#Rs. 80 million after two years.

#The CEO uses this analysis to decide whether to expand.








#Example 5: Cost Reduction

#CEO says:

#"Reduce company expenses by 10%."

#FP&A examines:

#Salaries
#Marketing
#Rent
#Delivery costs
#Technology costs

#Then recommends where savings are possible without hurting the business.

# %%
####################################################
